# %%
import sys
from pathlib import Path

# Add project root to Python path
# Notebook is in backend/eda/, so we need to go up 2 levels to reach project root
current_dir = Path.cwd()
if current_dir.name == "eda" and current_dir.parent.name == "backend":
    project_root = current_dir.parent.parent
elif current_dir.name == "backend":
    project_root = current_dir.parent
else:
    # Assume we're already at project root or adjust as needed
    project_root = current_dir

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
from backend.core.data_loader import load_train_data, load_test_data
from backend.core.text_preprocessor import preprocess_documents

# %%
train_data = load_train_data()
test_data = load_test_data()

# %%
train_data.documents[0]
# Out:
# 'I was wondering if anyone out there could enlighten me on this car I saw\nthe other day. It was a 2-door sports car, looked to be from the late 60s/\nearly 70s. It was called a Bricklin. The doors were really small. In addition,\nthe front bumper was separate from the rest of the body. This is \nall I know. If anyone can tellme a model name, engine specs, years\nof production, where this car is made, history, or whatever info you\nhave on this funky looking car, please e-mail.'

# %%
print(train_data.target[0])
print(train_data.target_names[0])
# Out:
# 7
# alt.atheism

# %%
preprocessed = preprocess_documents(train_data.documents)

# %%
preprocessed[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 preprocessed[0]
#
# TypeError: 'generator' object is not subscriptable

# %%
import numpy as np
# train_raw_counts = np.load('backend/cache/eda/stage1/train_raw_counts.npy')
train_raw_counts = np.load('/Users/anugrah/Desktop/Projects/topic-modeling-clustering/cache/eda/stage1/train_raw_counts.npy')
train_raw_counts.shape
# Out:
# (11314,)

# %%
train_raw_counts
# Out:
# array([ 91,  90, 307, ..., 113,  56,  51], shape=(11314,))

# %%
# Get the indices where tokens are 0
zero_indices = np.where(train_raw_counts == 0)[0]

print(len(zero_indices))

# # Get the corresponding tokens
# zero_tokens = train_raw_counts[zero_indices]

# print(zero_tokens)
# Out:
# 300
